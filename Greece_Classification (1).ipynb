# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
import os
import pathlib

import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers



import scipy.stats as ss
import sklearn
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn import linear_model
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import learning_curve, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn import preprocessing
from sklearn import tree
from sklearn.naive_bayes import GaussianNB
from mlxtend.plotting import plot_learning_curves
from sklearn.tree import export_graphviz
from six import StringIO
from IPython.display import Image  
import pydotplus
from sklearn.model_selection import validation_curve
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import callbacks
from keras.models import Sequential
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
from sklearn.model_selection import KFold
from tensorflow.keras.layers import Dense, Input, Flatten, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D, GlobalMaxPooling2D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import BatchNormalization

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/GR_v10_Tested.csv")

# %%
df.shape
# Out:
# (17714, 735)

# %% [markdown]
# # Creating our dataframe

# %%
#df_ok = df[['B1_1.1','B1_2.1','B1_3.1','B1_4.1','B1_5.1','B1_6.1','B1_7.1','B1_8.1','B1_9.1','B1_10.1','B1_11.1','B1_12.1','B1_13.1','B1_14.1','B8.1']]

df_ok = df[['B1_1.1','B1_2.1','B1_3.1','B1_4.1','B1_5.1','B1_6.1','B1_7.1','B1_8.1','B1_9.1','B1_10.1','B1_11.1','B1_12.1','B8.1']]

# %%
df_ok.shape
# Out:
# (17714, 13)

# %% [markdown]
# # Data Visualization

# %%
df_ok.hist(figsize=(20, 18), bins=40, xlabelsize=8, ylabelsize=8, )
plt.show()

# %%
f, ax = plt.subplots(figsize=(15, 15))
corr = df_ok.corr()
sns.heatmap(corr,annot=True, vmin = -1, vmax = 1, square = True, center =0, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
plt.title('Correlation Map')
plt.show()

# %% [markdown]
# ### Output

# %%
df_ok.hist('B8.1')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9fc0ec8610>]],
#       dtype=object)

# %%
freq = df_ok.groupby(['B8.1']).count()
freq
# Out:
#       B1_1.1  B1_2.1  B1_3.1  B1_4.1  ...  B1_9.1  B1_10.1  B1_11.1  B1_12.1
# B8.1                                  ...
# 0      17087   17087   17087   17087  ...   17087    17087    17087    17087
# 1        627     627     627     627  ...     627      627      627      627
#
# [2 rows x 12 columns]

# %% [markdown]
# Positive in the last 14 days -> 627
#
# Negative in the last 14 days -> 17087

# %% [markdown]
# # Training & Test

# %%
X = df_ok.drop(['B8.1'], axis=1)
Y = df_ok['B8.1']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=2)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (14171, 12)
# (3543, 12)
# (14171,)
# (3543,)

# %%
'''
X_norm = preprocessing.scale(X_train)
scaler = preprocessing.StandardScaler().fit(X_train)
X_train_norm = scaler.transform(X_train)
X_test_norm = scaler.transform(X_test)
print(X_train_norm.shape)
print(X_test_norm.shape)
'''

# %% [markdown]
# ## Decision Tree

# %%
max_depth = np.arange(1, 10)
min_samples_leaf = [50, 100, 200]

# GridSearchCV
param_grid = { 'criterion':['gini','entropy'],'max_depth': max_depth,'min_samples_leaf': min_samples_leaf}

# %%
dtree_model=tree.DecisionTreeClassifier()

dtree_model = GridSearchCV(dtree_model, param_grid, cv=3)

dtree_model=dtree_model.fit(X_train, Y_train)
print(dtree_model.best_params_)
# Out:
# {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 50}

# %%
my_model = dtree_model.best_estimator_
my_tree=my_model.fit(X_train, Y_train)

y_predicted = my_model.predict(X_test)

print('Accuracy:',accuracy_score(Y_test, y_predicted))
print(classification_report(Y_test, y_predicted))
matrix = confusion_matrix(Y_test, y_predicted)
print(matrix)
plt.figure(figsize=(7,7))
sns.heatmap(matrix,annot=True, square = True, fmt='g')
plt.show()
#print(confusion_matrix(Y_test, y_predicted))
# Out:
# Accuracy: 0.9709285915890489
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      3425
#            1       0.67      0.25      0.36       118
#
#     accuracy                           0.97      3543
#    macro avg       0.82      0.62      0.67      3543
# weighted avg       0.96      0.97      0.96      3543
#
# [[3411   14]
#  [  89   29]]

# %%
my_tree.get_depth()
my_tree.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 1,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 50,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'presort': 'deprecated',
#  'random_state': None,
#  'splitter': 'best'}

# %%
from matplotlib import pyplot
importance=my_tree.feature_importances_
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()

# %% [markdown]
# ## Random Forest

# %%
rfc=RandomForestClassifier(random_state=42)

# %%
param_grid = { 
    'n_estimators': [200, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [4,5,6,7,8],
    'criterion' :['gini', 'entropy']
}

# %%
CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, cv= 3)
CV_rfc.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=3, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=100, n_jobs=None,
#                                               oob_score=False, random_state=42,
#                                               verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [4, 5, 6, 7, 8],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [200, 500]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
CV_rfc.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 8,
#  'max_features': 'auto',
#  'n_estimators': 500}

# %%
my_model = CV_rfc.best_estimator_
RF =my_model.fit(X_train, Y_train)

# %%
y_pred = RF.predict(X_test)

# %%
print('Accuracy:',accuracy_score(Y_test, y_pred))
print(classification_report(Y_test, y_pred))
matrix = confusion_matrix(Y_test, y_pred)
print(matrix)
plt.figure(figsize=(7,7))
sns.heatmap(matrix,annot=True, square = True, fmt='g')
plt.show()
#print(confusion_matrix(Y_test, y_pred))
# Out:
# Accuracy: 0.9686706181202371
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      3425
#            1       0.59      0.20      0.30       118
#
#     accuracy                           0.97      3543
#    macro avg       0.78      0.60      0.64      3543
# weighted avg       0.96      0.97      0.96      3543
#
# [[3408   17]
#  [  94   24]]

# %% [markdown]
# ## KNN

# %%
k_values = range(1,51,2)
param_grid = {'n_neighbors': k_values}

kNN_model=KNeighborsClassifier()

grid = GridSearchCV(kNN_model, param_grid, cv = 3, scoring = 'accuracy')
grid.fit(X_train,Y_train)
print(grid.best_params_)
# Out:
# {'n_neighbors': 5}

# %%
my_model = grid.best_estimator_

# %%
my_model.fit(X_train, Y_train)
y_predicted = my_model.predict(X_test)
print('Accuracy:',accuracy_score(Y_test, y_predicted))
print(classification_report(Y_test, y_predicted))

matrix = confusion_matrix(Y_test, y_predicted)
print(matrix)
plt.figure(figsize=(7,7))
sns.heatmap(matrix,annot=True, square = True, fmt='g')
plt.show()
# Out:
# Accuracy: 0.9669771380186283
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      3425
#            1       0.52      0.11      0.18       118
#
#     accuracy                           0.97      3543
#    macro avg       0.75      0.55      0.58      3543
# weighted avg       0.96      0.97      0.96      3543
#
# [[3413   12]
#  [ 105   13]]

# %% [markdown]
# ## SVM

# %%
# defining parameter range
param_grid = {'C': [0.1, 1, 10, 100, 1000], 
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf']} 
  
grid = GridSearchCV(SVC(), param_grid, refit = True)
  
# fitting the model for grid search
grid.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                            class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='scale', kernel='rbf', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
# print best parameter after tuning
print(grid.best_params_)
  
# print how our model looks after hyper-parameter tuning
print(grid.best_estimator_)
# Out:
# {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# SVC(C=1, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.1, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
y_pred = grid.predict(X_test)
  
# print classification report
print('Accuracy:',accuracy_score(Y_test, y_pred))
print(classification_report(Y_test, y_pred))

matrix = confusion_matrix(Y_test, y_pred)
print(matrix)
plt.figure(figsize=(7,7))
sns.heatmap(matrix,annot=True, square = True, fmt='g')
plt.show()
# Out:
# Accuracy: 0.9709285915890489
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      3425
#            1       0.67      0.25      0.36       118
#
#     accuracy                           0.97      3543
#    macro avg       0.82      0.62      0.67      3543
# weighted avg       0.96      0.97      0.96      3543
#
# [[3411   14]
#  [  89   29]]

# %% [markdown]
# ## Neural Network

# %%
neg, pos = np.bincount(df_ok['B8.1'])
total = neg + pos
print('Examples:\n    Total: {}\n    Positive: {} ({:.2f}% of total)\n'.format(
    total, pos, 100 * pos / total))
# Out:
# Examples:
#     Total: 17714
#     Positive: 627 (3.54% of total)

# %%
weight_for_0 = (1 / neg) * (total / 2.0)
weight_for_1 = (1 / pos) * (total / 2.0)

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 0.52
# Weight for class 1: 14.13

# %%
def baseline_model():
  model = Sequential()
  model.add(Dense(2000, input_dim=X_train.shape[1], activation='relu'))
  model.add(BatchNormalization())
  model.add(Dropout(0.3))
  model.add(Dense(1024, activation='relu'))
  model.add(Dropout(0.4))
  model.add(Dense(512, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(256, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(128, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(64, activation='relu')),
  model.add(Dropout(0.5)),
  model.add(Dense(1, activation='sigmoid'))
  # Compile model
  model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['binary_accuracy'])
  return model

# %%
model = baseline_model()

history = model.fit(
  X_train, Y_train, batch_size = 512,
  epochs=50, validation_split = 0.1,
  class_weight=class_weight)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/50
# 25/25 [==============================] - 20s 33ms/step - loss: 0.9983 - binary_accuracy: 0.5125 - val_loss: 0.6901 - val_binary_accuracy: 0.9450
# Epoch 2/50
# 25/25 [==============================] - 0s 8ms/step - loss: 0.7417 - binary_accuracy: 0.5590 - val_loss: 0.6817 - val_binary_accuracy: 0.9640
# Epoch 3/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.6745 - binary_accuracy: 0.6527 - val_loss: 0.6750 - val_binary_accuracy: 0.9640
# Epoch 4/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.6430 - binary_accuracy: 0.6483 - val_loss: 0.6679 - val_binary_accuracy: 0.9669
# Epoch 5/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.6611 - binary_accuracy: 0.7110 - val_loss: 0.6650 - val_binary_accuracy: 0.9661
# Epoch 6/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5915 - binary_accuracy: 0.7409 - val_loss: 0.6546 - val_binary_accuracy: 0.9661
# Epoch 7/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.6155 - binary_accuracy: 0.7599 - val_loss: 0.6469 - val_binary_accuracy: 0.9669
# Epoch 8/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.6254 - binary_accuracy: 0.7921 - val_loss: 0.6372 - val_binary_accuracy: 0.9669
# Epoch 9/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5671 - binary_accuracy: 0.8307 - val_loss: 0.6381 - val_binary_accuracy: 0.9676
# Epoch 10/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5836 - binary_accuracy: 0.8114 - val_loss: 0.6256 - val_binary_accuracy: 0.9669
# Epoch 11/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5520 - binary_accuracy: 0.8453 - val_loss: 0.6265 - val_binary_accuracy: 0.9676
# Epoch 12/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5755 - binary_accuracy: 0.8268 - val_loss: 0.6164 - val_binary_accuracy: 0.9654
# Epoch 13/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5744 - binary_accuracy: 0.8400 - val_loss: 0.6088 - val_binary_accuracy: 0.9640
# Epoch 14/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5513 - binary_accuracy: 0.8428 - val_loss: 0.6037 - val_binary_accuracy: 0.9640
# Epoch 15/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5949 - binary_accuracy: 0.8375 - val_loss: 0.6050 - val_binary_accuracy: 0.9654
# Epoch 16/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5688 - binary_accuracy: 0.8576 - val_loss: 0.5948 - val_binary_accuracy: 0.9661
# Epoch 17/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5300 - binary_accuracy: 0.8778 - val_loss: 0.6052 - val_binary_accuracy: 0.9506
# Epoch 18/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5827 - binary_accuracy: 0.8504 - val_loss: 0.5986 - val_binary_accuracy: 0.9591
# Epoch 19/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5646 - binary_accuracy: 0.8668 - val_loss: 0.5606 - val_binary_accuracy: 0.9619
# Epoch 20/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5410 - binary_accuracy: 0.8835 - val_loss: 0.5512 - val_binary_accuracy: 0.9570
# Epoch 21/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5576 - binary_accuracy: 0.8743 - val_loss: 0.5645 - val_binary_accuracy: 0.9528
# Epoch 22/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5651 - binary_accuracy: 0.8552 - val_loss: 0.5551 - val_binary_accuracy: 0.9478
# Epoch 23/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5790 - binary_accuracy: 0.8730 - val_loss: 0.5579 - val_binary_accuracy: 0.9408
# Epoch 24/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5480 - binary_accuracy: 0.8792 - val_loss: 0.5428 - val_binary_accuracy: 0.9365
# Epoch 25/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5628 - binary_accuracy: 0.8731 - val_loss: 0.5453 - val_binary_accuracy: 0.9316
# Epoch 26/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5363 - binary_accuracy: 0.8759 - val_loss: 0.5460 - val_binary_accuracy: 0.9309
# Epoch 27/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5228 - binary_accuracy: 0.8875 - val_loss: 0.5349 - val_binary_accuracy: 0.9323
# Epoch 28/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5544 - binary_accuracy: 0.8785 - val_loss: 0.5623 - val_binary_accuracy: 0.9408
# Epoch 29/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5398 - binary_accuracy: 0.8875 - val_loss: 0.5284 - val_binary_accuracy: 0.9245
# Epoch 30/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5182 - binary_accuracy: 0.8883 - val_loss: 0.5316 - val_binary_accuracy: 0.9358
# Epoch 31/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5305 - binary_accuracy: 0.8956 - val_loss: 0.5032 - val_binary_accuracy: 0.9316
# Epoch 32/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5618 - binary_accuracy: 0.8933 - val_loss: 0.5155 - val_binary_accuracy: 0.9231
# Epoch 33/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5354 - binary_accuracy: 0.8950 - val_loss: 0.4922 - val_binary_accuracy: 0.9295
# Epoch 34/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5621 - binary_accuracy: 0.8822 - val_loss: 0.5097 - val_binary_accuracy: 0.9245
# Epoch 35/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5518 - binary_accuracy: 0.8850 - val_loss: 0.5212 - val_binary_accuracy: 0.9231
# Epoch 36/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5129 - binary_accuracy: 0.8969 - val_loss: 0.5026 - val_binary_accuracy: 0.9161
# Epoch 37/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5492 - binary_accuracy: 0.8778 - val_loss: 0.5168 - val_binary_accuracy: 0.9379
# Epoch 38/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5573 - binary_accuracy: 0.8890 - val_loss: 0.5004 - val_binary_accuracy: 0.9309
# Epoch 39/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5269 - binary_accuracy: 0.8875 - val_loss: 0.5087 - val_binary_accuracy: 0.9168
# Epoch 40/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5386 - binary_accuracy: 0.8787 - val_loss: 0.5207 - val_binary_accuracy: 0.9281
# Epoch 41/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5467 - binary_accuracy: 0.8829 - val_loss: 0.4907 - val_binary_accuracy: 0.9344
# Epoch 42/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5295 - binary_accuracy: 0.9033 - val_loss: 0.5046 - val_binary_accuracy: 0.9288
# Epoch 43/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5480 - binary_accuracy: 0.8850 - val_loss: 0.4964 - val_binary_accuracy: 0.9358
# Epoch 44/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5196 - binary_accuracy: 0.9027 - val_loss: 0.5003 - val_binary_accuracy: 0.9252
# Epoch 45/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5331 - binary_accuracy: 0.8969 - val_loss: 0.4995 - val_binary_accuracy: 0.9316
# Epoch 46/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5441 - binary_accuracy: 0.8839 - val_loss: 0.4783 - val_binary_accuracy: 0.9252
# Epoch 47/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5485 - binary_accuracy: 0.9043 - val_loss: 0.4887 - val_binary_accuracy: 0.9295
# Epoch 48/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5287 - binary_accuracy: 0.9007 - val_loss: 0.5051 - val_binary_accuracy: 0.9062
# Epoch 49/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5329 - binary_accuracy: 0.8830 - val_loss: 0.5099 - val_binary_accuracy: 0.9260
# Epoch 50/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5483 - binary_accuracy: 0.8832 - val_loss: 0.5115 - val_binary_accuracy: 0.9090

# %%
acc = history.history['binary_accuracy']
val_acc = history.history['val_binary_accuracy'] 
loss = history.history['loss'] 
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, 'bo', label='Training acc') 
plt.plot(epochs, val_acc, 'b', label='Validation acc') 
plt.title('Training and validation accuracy') 
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss') 
plt.plot(epochs, val_loss, 'b', label='Validation loss') 
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
def smooth_curve(points, factor=0.8): 
  smoothed_points = []
  for point in points:
      if smoothed_points:
          previous = smoothed_points[-1]
          smoothed_points.append(previous * factor + point * (1 - factor))
      else: 
          smoothed_points.append(point)
  return smoothed_points
plt.plot(epochs,
         smooth_curve(acc), 'bo', label='Smoothed training acc')
plt.plot(epochs,
         smooth_curve(val_acc), 'b', label='Smoothed validation acc')
plt.title('Training and validation accuracy') 
plt.legend()
plt.figure()
plt.plot(epochs,
         smooth_curve(loss), 'bo', label='Smoothed training loss')
plt.plot(epochs,
         smooth_curve(val_loss), 'b', label='Smoothed validation loss')
plt.title('Training and validation loss') 
plt.legend()
plt.show()

# %%
model.evaluate(X_test, Y_test)
# Out:
# 111/111 [==============================] - 0s 2ms/step - loss: 0.5025 - binary_accuracy: 0.9139
# [0.5024668574333191, 0.9139147400856018]

# %%
y_pred = model.predict(X_test)
matrix = confusion_matrix(Y_test, y_pred.argmax(axis=1))
print(matrix)
plt.figure(figsize=(7,7))
sns.heatmap(matrix,annot=True, square = True, fmt='g')
plt.show()
# Out:
# [[3425    0]
#  [ 118    0]]

# %% [markdown]
# ## Neural Network V2

# %%
neg, pos = np.bincount(df_ok['B8.1'])
total = neg + pos
print('Examples:\n    Total: {}\n    Positive: {} ({:.2f}% of total)\n'.format(
    total, pos, 100 * pos / total))
# Out:
# Examples:
#     Total: 17714
#     Positive: 627 (3.54% of total)

# %%
weight_for_0 = (1 / neg) * (total / 2.0)
weight_for_1 = (1 / pos) * (total / 2.0)

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 0.52
# Weight for class 1: 14.13

# %%
def baseline_model2():
  model = Sequential()
  model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
  model.add(BatchNormalization())
  model.add(Dropout(0.5))
  model.add(Dense(1, activation='sigmoid'))
  # Compile model
  model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['binary_accuracy'])
  return model

# %%
model2 = baseline_model2()

history = model2.fit(
  X_train, Y_train, batch_size = 512,
  epochs=50, validation_split = 0.1,
  class_weight=class_weight)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/50
# 25/25 [==============================] - 16s 21ms/step - loss: 0.7965 - binary_accuracy: 0.5890 - val_loss: 0.6438 - val_binary_accuracy: 0.9055
# Epoch 2/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.7501 - binary_accuracy: 0.7123 - val_loss: 0.6024 - val_binary_accuracy: 0.9274
# Epoch 3/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6828 - binary_accuracy: 0.7699 - val_loss: 0.5671 - val_binary_accuracy: 0.9492
# Epoch 4/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6677 - binary_accuracy: 0.7955 - val_loss: 0.5503 - val_binary_accuracy: 0.9478
# Epoch 5/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6753 - binary_accuracy: 0.8071 - val_loss: 0.5404 - val_binary_accuracy: 0.9485
# Epoch 6/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6246 - binary_accuracy: 0.8261 - val_loss: 0.5228 - val_binary_accuracy: 0.9302
# Epoch 7/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6545 - binary_accuracy: 0.8241 - val_loss: 0.5227 - val_binary_accuracy: 0.9302
# Epoch 8/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6072 - binary_accuracy: 0.8354 - val_loss: 0.5128 - val_binary_accuracy: 0.9337
# Epoch 9/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6247 - binary_accuracy: 0.8467 - val_loss: 0.5055 - val_binary_accuracy: 0.9274
# Epoch 10/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5989 - binary_accuracy: 0.8447 - val_loss: 0.4997 - val_binary_accuracy: 0.9288
# Epoch 11/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5925 - binary_accuracy: 0.8502 - val_loss: 0.4967 - val_binary_accuracy: 0.9274
# Epoch 12/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5756 - binary_accuracy: 0.8520 - val_loss: 0.4913 - val_binary_accuracy: 0.9245
# Epoch 13/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5887 - binary_accuracy: 0.8543 - val_loss: 0.4898 - val_binary_accuracy: 0.9168
# Epoch 14/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5619 - binary_accuracy: 0.8604 - val_loss: 0.4877 - val_binary_accuracy: 0.9168
# Epoch 15/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5797 - binary_accuracy: 0.8548 - val_loss: 0.4902 - val_binary_accuracy: 0.9083
# Epoch 16/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5551 - binary_accuracy: 0.8551 - val_loss: 0.4959 - val_binary_accuracy: 0.9097
# Epoch 17/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5433 - binary_accuracy: 0.8654 - val_loss: 0.4866 - val_binary_accuracy: 0.9041
# Epoch 18/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5740 - binary_accuracy: 0.8679 - val_loss: 0.4889 - val_binary_accuracy: 0.8999
# Epoch 19/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5747 - binary_accuracy: 0.8661 - val_loss: 0.4958 - val_binary_accuracy: 0.9006
# Epoch 20/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5799 - binary_accuracy: 0.8605 - val_loss: 0.4992 - val_binary_accuracy: 0.8836
# Epoch 21/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5398 - binary_accuracy: 0.8579 - val_loss: 0.4972 - val_binary_accuracy: 0.8886
# Epoch 22/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5636 - binary_accuracy: 0.8605 - val_loss: 0.4954 - val_binary_accuracy: 0.8977
# Epoch 23/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5620 - binary_accuracy: 0.8637 - val_loss: 0.4944 - val_binary_accuracy: 0.8977
# Epoch 24/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5239 - binary_accuracy: 0.8685 - val_loss: 0.4927 - val_binary_accuracy: 0.8872
# Epoch 25/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5687 - binary_accuracy: 0.8669 - val_loss: 0.4925 - val_binary_accuracy: 0.8872
# Epoch 26/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5746 - binary_accuracy: 0.8617 - val_loss: 0.5000 - val_binary_accuracy: 0.8900
# Epoch 27/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5571 - binary_accuracy: 0.8669 - val_loss: 0.4994 - val_binary_accuracy: 0.8865
# Epoch 28/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5344 - binary_accuracy: 0.8667 - val_loss: 0.4928 - val_binary_accuracy: 0.8745
# Epoch 29/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5426 - binary_accuracy: 0.8632 - val_loss: 0.4957 - val_binary_accuracy: 0.8639
# Epoch 30/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5356 - binary_accuracy: 0.8666 - val_loss: 0.4995 - val_binary_accuracy: 0.8858
# Epoch 31/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5415 - binary_accuracy: 0.8631 - val_loss: 0.5016 - val_binary_accuracy: 0.8752
# Epoch 32/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5472 - binary_accuracy: 0.8601 - val_loss: 0.4969 - val_binary_accuracy: 0.8639
# Epoch 33/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5245 - binary_accuracy: 0.8713 - val_loss: 0.4926 - val_binary_accuracy: 0.8646
# Epoch 34/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5309 - binary_accuracy: 0.8690 - val_loss: 0.4988 - val_binary_accuracy: 0.8632
# Epoch 35/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5656 - binary_accuracy: 0.8614 - val_loss: 0.5040 - val_binary_accuracy: 0.8653
# Epoch 36/50
# 25/25 [==============================] - 0s 5ms/step - loss: 0.5563 - binary_accuracy: 0.8643 - val_loss: 0.5007 - val_binary_accuracy: 0.8632
# Epoch 37/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5551 - binary_accuracy: 0.8636 - val_loss: 0.4997 - val_binary_accuracy: 0.8625
# Epoch 38/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5437 - binary_accuracy: 0.8619 - val_loss: 0.4942 - val_binary_accuracy: 0.8858
# Epoch 39/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5213 - binary_accuracy: 0.8680 - val_loss: 0.4912 - val_binary_accuracy: 0.8632
# Epoch 40/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5287 - binary_accuracy: 0.8703 - val_loss: 0.4976 - val_binary_accuracy: 0.8653
# Epoch 41/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5127 - binary_accuracy: 0.8752 - val_loss: 0.4908 - val_binary_accuracy: 0.8646
# Epoch 42/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5256 - binary_accuracy: 0.8619 - val_loss: 0.4964 - val_binary_accuracy: 0.8653
# Epoch 43/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5497 - binary_accuracy: 0.8644 - val_loss: 0.5004 - val_binary_accuracy: 0.8646
# Epoch 44/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5468 - binary_accuracy: 0.8636 - val_loss: 0.4943 - val_binary_accuracy: 0.8646
# Epoch 45/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5441 - binary_accuracy: 0.8647 - val_loss: 0.4915 - val_binary_accuracy: 0.8646
# Epoch 46/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5397 - binary_accuracy: 0.8627 - val_loss: 0.4896 - val_binary_accuracy: 0.8653
# Epoch 47/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5393 - binary_accuracy: 0.8674 - val_loss: 0.4858 - val_binary_accuracy: 0.8646
# Epoch 48/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5445 - binary_accuracy: 0.8529 - val_loss: 0.4858 - val_binary_accuracy: 0.8646
# Epoch 49/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5529 - binary_accuracy: 0.8590 - val_loss: 0.4923 - val_binary_accuracy: 0.8724
# Epoch 50/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5489 - binary_accuracy: 0.8674 - val_loss: 0.5004 - val_binary_accuracy: 0.8639

# %%
acc = history.history['binary_accuracy']
val_acc = history.history['val_binary_accuracy'] 
loss = history.history['loss'] 
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, 'bo', label='Training acc') 
plt.plot(epochs, val_acc, 'b', label='Validation acc') 
plt.title('Training and validation accuracy') 
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss') 
plt.plot(epochs, val_loss, 'b', label='Validation loss') 
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
def smooth_curve(points, factor=0.8): 
  smoothed_points = []
  for point in points:
      if smoothed_points:
          previous = smoothed_points[-1]
          smoothed_points.append(previous * factor + point * (1 - factor))
      else: 
          smoothed_points.append(point)
  return smoothed_points
plt.plot(epochs,
         smooth_curve(acc), 'bo', label='Smoothed training acc')
plt.plot(epochs,
         smooth_curve(val_acc), 'b', label='Smoothed validation acc')
plt.title('Training and validation accuracy') 
plt.legend()
plt.figure()
plt.plot(epochs,
         smooth_curve(loss), 'bo', label='Smoothed training loss')
plt.plot(epochs,
         smooth_curve(val_loss), 'b', label='Smoothed validation loss')
plt.title('Training and validation loss') 
plt.legend()
plt.show()

# %%
model2.evaluate(X_test, Y_test)
# Out:
# 111/111 [==============================] - 0s 2ms/step - loss: 0.4931 - binary_accuracy: 0.8623
# [0.493057519197464, 0.8622636198997498]

# %%
y_pred = model2.predict(X_test)

matrix = confusion_matrix(Y_test, y_pred.argmax(axis=1))
print(matrix)
plt.figure(figsize=(7,7))
sns.heatmap(matrix,annot=True, square = True, fmt='g')
plt.show()
# Out:
# [[3425    0]
#  [ 118    0]]
