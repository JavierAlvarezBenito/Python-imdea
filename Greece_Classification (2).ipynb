# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
import os
import pathlib

import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers



import scipy.stats as ss
import sklearn
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn import linear_model
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import precision_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import learning_curve, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn import preprocessing
from sklearn import tree
from sklearn.naive_bayes import GaussianNB
from mlxtend.plotting import plot_learning_curves
from sklearn.tree import export_graphviz
from six import StringIO
from IPython.display import Image  
import pydotplus
from sklearn.model_selection import validation_curve
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import callbacks
from keras.models import Sequential
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
from sklearn.model_selection import KFold
from tensorflow.keras.layers import Dense, Input, Flatten, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D, GlobalMaxPooling2D
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import BatchNormalization

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/GR_v10_Tested.csv")

# %%
df.shape
# Out:
# (17714, 735)

# %% [markdown]
# # Creating our dataframe

# %%
#df_ok = df[['B1_1.1','B1_2.1','B1_3.1','B1_4.1','B1_5.1','B1_6.1','B1_7.1','B1_8.1','B1_9.1','B1_10.1','B1_11.1','B1_12.1','B1_13.1','B1_14.1','B8.1']]

df_ok = df[['B1_1.1','B1_2.1','B1_3.1','B1_4.1','B1_5.1','B1_6.1','B1_7.1','B1_8.1','B1_9.1','B1_10.1','B1_11.1','B1_12.1','B8.1']]

# %%
df_ok.shape
# Out:
# (17714, 13)

# %% [markdown]
# # Data Visualization

# %%
df_ok.hist(figsize=(20, 18), bins=40, xlabelsize=8, ylabelsize=8, )
plt.show()

# %%
f, ax = plt.subplots(figsize=(15, 15))
corr = df_ok.corr()
sns.heatmap(corr,annot=True, vmin = -1, vmax = 1, square = True, center =0, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
plt.title('Correlation Map')
plt.show()

# %% [markdown]
# ### Output

# %%
df_ok.hist('B8.1')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9fc0ec8610>]],
#       dtype=object)

# %%
freq = df_ok.groupby(['B8.1']).count()
freq
# Out:
#       B1_1.1  B1_2.1  B1_3.1  B1_4.1  ...  B1_9.1  B1_10.1  B1_11.1  B1_12.1
# B8.1                                  ...
# 0      17087   17087   17087   17087  ...   17087    17087    17087    17087
# 1        627     627     627     627  ...     627      627      627      627
#
# [2 rows x 12 columns]

# %% [markdown]
# Positive in the last 14 days -> 627
#
# Negative in the last 14 days -> 17087

# %% [markdown]
# # Training & Test

# %%
X = df_ok.drop(['B8.1'], axis=1)
Y = df_ok['B8.1']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state=2)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (14171, 12)
# (3543, 12)
# (14171,)
# (3543,)

# %%
'''
X_norm = preprocessing.scale(X_train)
scaler = preprocessing.StandardScaler().fit(X_train)
X_train_norm = scaler.transform(X_train)
X_test_norm = scaler.transform(X_test)
print(X_train_norm.shape)
print(X_test_norm.shape)
'''

# %% [markdown]
# ## Decision Tree

# %%
max_depth = np.arange(1, 10)
min_samples_leaf = [50, 100, 200]

# GridSearchCV
param_grid = { 'criterion':['gini','entropy'],'max_depth': max_depth,'min_samples_leaf': min_samples_leaf}

# %%
dtree_model=tree.DecisionTreeClassifier()

dtree_model = GridSearchCV(dtree_model, param_grid, cv=3)

dtree_model=dtree_model.fit(X_train, Y_train)
print(dtree_model.best_params_)
# Out:
# {'criterion': 'gini', 'max_depth': 1, 'min_samples_leaf': 50}

# %%
my_model = dtree_model.best_estimator_
my_tree=my_model.fit(X_train, Y_train)

y_predicted = my_model.predict(X_test)

print('Accuracy:',accuracy_score(Y_test, y_predicted))
print(classification_report(Y_test, y_predicted))
matrix = confusion_matrix(Y_test, y_predicted)
print(matrix)
plt.figure(figsize=(7,7))
sns.heatmap(matrix,annot=True, square = True, fmt='g')
plt.show()
#print(confusion_matrix(Y_test, y_predicted))
# Out:
# Accuracy: 0.9709285915890489
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      3425
#            1       0.67      0.25      0.36       118
#
#     accuracy                           0.97      3543
#    macro avg       0.82      0.62      0.67      3543
# weighted avg       0.96      0.97      0.96      3543
#
# [[3411   14]
#  [  89   29]]

# %%
my_tree.get_depth()
my_tree.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 1,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 50,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'presort': 'deprecated',
#  'random_state': None,
#  'splitter': 'best'}

# %%
from matplotlib import pyplot
importance=my_tree.feature_importances_
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()

# %% [markdown]
# ## Random Forest

# %%
rfc=RandomForestClassifier(random_state=42)

# %%
param_grid = { 
    'n_estimators': [200, 500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : [4,5,6,7,8],
    'criterion' :['gini', 'entropy']
}

# %%
CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, cv= 3)
CV_rfc.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=3, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=100, n_jobs=None,
#                                               oob_score=False, random_state=42,
#                                               verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [4, 5, 6, 7, 8],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [200, 500]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
CV_rfc.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 8,
#  'max_features': 'auto',
#  'n_estimators': 500}

# %%
my_model = CV_rfc.best_estimator_
RF =my_model.fit(X_train, Y_train)

# %%
y_pred = RF.predict(X_test)

# %%
print('Accuracy:',accuracy_score(Y_test, y_pred))
print(classification_report(Y_test, y_pred))
matrix = confusion_matrix(Y_test, y_pred)
print(matrix)
plt.figure(figsize=(7,7))
sns.heatmap(matrix,annot=True, square = True, fmt='g')
plt.show()
#print(confusion_matrix(Y_test, y_pred))
# Out:
# Accuracy: 0.9686706181202371
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      3425
#            1       0.59      0.20      0.30       118
#
#     accuracy                           0.97      3543
#    macro avg       0.78      0.60      0.64      3543
# weighted avg       0.96      0.97      0.96      3543
#
# [[3408   17]
#  [  94   24]]

# %% [markdown]
# ## KNN

# %%
k_values = range(1,51,2)
param_grid = {'n_neighbors': k_values}

kNN_model=KNeighborsClassifier()

grid = GridSearchCV(kNN_model, param_grid, cv = 3, scoring = 'accuracy')
grid.fit(X_train,Y_train)
print(grid.best_params_)
# Out:
# {'n_neighbors': 5}

# %%
my_model = grid.best_estimator_

# %%
my_model.fit(X_train, Y_train)
y_predicted = my_model.predict(X_test)
print('Accuracy:',accuracy_score(Y_test, y_predicted))
print(classification_report(Y_test, y_predicted))

matrix = confusion_matrix(Y_test, y_predicted)
print(matrix)
plt.figure(figsize=(7,7))
sns.heatmap(matrix,annot=True, square = True, fmt='g')
plt.show()
# Out:
# Accuracy: 0.9669771380186283
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      3425
#            1       0.52      0.11      0.18       118
#
#     accuracy                           0.97      3543
#    macro avg       0.75      0.55      0.58      3543
# weighted avg       0.96      0.97      0.96      3543
#
# [[3413   12]
#  [ 105   13]]

# %% [markdown]
# ## SVM

# %%
# defining parameter range
param_grid = {'C': [0.1, 1, 10, 100, 1000], 
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf']} 
  
grid = GridSearchCV(SVC(), param_grid, refit = True)
  
# fitting the model for grid search
grid.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=None, error_score=nan,
#              estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                            class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='scale', kernel='rbf', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
# print best parameter after tuning
print(grid.best_params_)
  
# print how our model looks after hyper-parameter tuning
print(grid.best_estimator_)
# Out:
# {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
# SVC(C=1, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=0.1, kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
y_pred = grid.predict(X_test)
  
# print classification report
print('Accuracy:',accuracy_score(Y_test, y_pred))
print(classification_report(Y_test, y_pred))

matrix = confusion_matrix(Y_test, y_pred)
print(matrix)
plt.figure(figsize=(7,7))
sns.heatmap(matrix,annot=True, square = True, fmt='g')
plt.show()
# Out:
# Accuracy: 0.9709285915890489
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      3425
#            1       0.67      0.25      0.36       118
#
#     accuracy                           0.97      3543
#    macro avg       0.82      0.62      0.67      3543
# weighted avg       0.96      0.97      0.96      3543
#
# [[3411   14]
#  [  89   29]]

# %% [markdown]
# ## Neural Network

# %%
neg, pos = np.bincount(df_ok['B8.1'])
total = neg + pos
print('Examples:\n    Total: {}\n    Positive: {} ({:.2f}% of total)\n'.format(
    total, pos, 100 * pos / total))
# Out:
# Examples:
#     Total: 17714
#     Positive: 627 (3.54% of total)

# %%
weight_for_0 = (1 / neg) * (total / 2.0)
weight_for_1 = (1 / pos) * (total / 2.0)

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 0.52
# Weight for class 1: 14.13

# %%
def baseline_model():
  model = Sequential()
  model.add(Dense(2000, input_dim=X_train.shape[1], activation='relu'))
  model.add(BatchNormalization())
  model.add(Dropout(0.3))
  model.add(Dense(1024, activation='relu'))
  model.add(Dropout(0.4))
  model.add(Dense(512, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(256, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(128, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(64, activation='relu')),
  model.add(Dropout(0.5)),
  model.add(Dense(1, activation='sigmoid'))
  # Compile model
  model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['binary_accuracy'])
  return model

# %%
model = baseline_model()

history = model.fit(
  X_train, Y_train, batch_size = 512,
  epochs=50, validation_split = 0.1,
  class_weight=class_weight)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/50
# 25/25 [==============================] - 20s 33ms/step - loss: 1.2337 - binary_accuracy: 0.6373 - val_loss: 0.6994 - val_binary_accuracy: 0.0331
# Epoch 2/50
# 25/25 [==============================] - 0s 8ms/step - loss: 0.7724 - binary_accuracy: 0.6358 - val_loss: 0.6928 - val_binary_accuracy: 0.8195
# Epoch 3/50
# 25/25 [==============================] - 0s 8ms/step - loss: 0.7043 - binary_accuracy: 0.6416 - val_loss: 0.6892 - val_binary_accuracy: 0.9140
# Epoch 4/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.6356 - binary_accuracy: 0.7027 - val_loss: 0.6840 - val_binary_accuracy: 0.9513
# Epoch 5/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.6114 - binary_accuracy: 0.7660 - val_loss: 0.6800 - val_binary_accuracy: 0.9605
# Epoch 6/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.6286 - binary_accuracy: 0.7242 - val_loss: 0.6752 - val_binary_accuracy: 0.9640
# Epoch 7/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5975 - binary_accuracy: 0.7976 - val_loss: 0.6745 - val_binary_accuracy: 0.9577
# Epoch 8/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5958 - binary_accuracy: 0.7738 - val_loss: 0.6669 - val_binary_accuracy: 0.9647
# Epoch 9/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.6024 - binary_accuracy: 0.8166 - val_loss: 0.6660 - val_binary_accuracy: 0.9647
# Epoch 10/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5992 - binary_accuracy: 0.8167 - val_loss: 0.6594 - val_binary_accuracy: 0.9654
# Epoch 11/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5958 - binary_accuracy: 0.8419 - val_loss: 0.6575 - val_binary_accuracy: 0.9626
# Epoch 12/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5853 - binary_accuracy: 0.8258 - val_loss: 0.6475 - val_binary_accuracy: 0.9626
# Epoch 13/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5701 - binary_accuracy: 0.8540 - val_loss: 0.6431 - val_binary_accuracy: 0.9584
# Epoch 14/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5624 - binary_accuracy: 0.8487 - val_loss: 0.6441 - val_binary_accuracy: 0.9591
# Epoch 15/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5655 - binary_accuracy: 0.8555 - val_loss: 0.6406 - val_binary_accuracy: 0.9605
# Epoch 16/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5591 - binary_accuracy: 0.8575 - val_loss: 0.6332 - val_binary_accuracy: 0.9549
# Epoch 17/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5723 - binary_accuracy: 0.8668 - val_loss: 0.6268 - val_binary_accuracy: 0.9563
# Epoch 18/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5697 - binary_accuracy: 0.8486 - val_loss: 0.6158 - val_binary_accuracy: 0.9513
# Epoch 19/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5393 - binary_accuracy: 0.8678 - val_loss: 0.5951 - val_binary_accuracy: 0.9401
# Epoch 20/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5473 - binary_accuracy: 0.8678 - val_loss: 0.6011 - val_binary_accuracy: 0.9295
# Epoch 21/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5488 - binary_accuracy: 0.8603 - val_loss: 0.5916 - val_binary_accuracy: 0.9415
# Epoch 22/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5448 - binary_accuracy: 0.8648 - val_loss: 0.5748 - val_binary_accuracy: 0.9351
# Epoch 23/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5328 - binary_accuracy: 0.8713 - val_loss: 0.5831 - val_binary_accuracy: 0.9351
# Epoch 24/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5458 - binary_accuracy: 0.8721 - val_loss: 0.5612 - val_binary_accuracy: 0.9337
# Epoch 25/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5833 - binary_accuracy: 0.8939 - val_loss: 0.5577 - val_binary_accuracy: 0.9379
# Epoch 26/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5237 - binary_accuracy: 0.8955 - val_loss: 0.5770 - val_binary_accuracy: 0.9295
# Epoch 27/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5173 - binary_accuracy: 0.8832 - val_loss: 0.5570 - val_binary_accuracy: 0.9189
# Epoch 28/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5459 - binary_accuracy: 0.8718 - val_loss: 0.5769 - val_binary_accuracy: 0.9295
# Epoch 29/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5267 - binary_accuracy: 0.8907 - val_loss: 0.5815 - val_binary_accuracy: 0.9260
# Epoch 30/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5495 - binary_accuracy: 0.8695 - val_loss: 0.5582 - val_binary_accuracy: 0.9302
# Epoch 31/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5720 - binary_accuracy: 0.8874 - val_loss: 0.5429 - val_binary_accuracy: 0.9302
# Epoch 32/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5395 - binary_accuracy: 0.8905 - val_loss: 0.5272 - val_binary_accuracy: 0.9288
# Epoch 33/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5301 - binary_accuracy: 0.8849 - val_loss: 0.5348 - val_binary_accuracy: 0.9330
# Epoch 34/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5824 - binary_accuracy: 0.8811 - val_loss: 0.5517 - val_binary_accuracy: 0.9260
# Epoch 35/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5358 - binary_accuracy: 0.8810 - val_loss: 0.5285 - val_binary_accuracy: 0.9252
# Epoch 36/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5612 - binary_accuracy: 0.8923 - val_loss: 0.5534 - val_binary_accuracy: 0.9182
# Epoch 37/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5392 - binary_accuracy: 0.8916 - val_loss: 0.5189 - val_binary_accuracy: 0.9224
# Epoch 38/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5461 - binary_accuracy: 0.8873 - val_loss: 0.5073 - val_binary_accuracy: 0.9260
# Epoch 39/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5386 - binary_accuracy: 0.8987 - val_loss: 0.5164 - val_binary_accuracy: 0.9260
# Epoch 40/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5514 - binary_accuracy: 0.9016 - val_loss: 0.5298 - val_binary_accuracy: 0.9147
# Epoch 41/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5094 - binary_accuracy: 0.8945 - val_loss: 0.5185 - val_binary_accuracy: 0.9182
# Epoch 42/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5190 - binary_accuracy: 0.8873 - val_loss: 0.5347 - val_binary_accuracy: 0.9245
# Epoch 43/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5274 - binary_accuracy: 0.8870 - val_loss: 0.5304 - val_binary_accuracy: 0.9274
# Epoch 44/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.4987 - binary_accuracy: 0.9036 - val_loss: 0.5257 - val_binary_accuracy: 0.9189
# Epoch 45/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5182 - binary_accuracy: 0.8883 - val_loss: 0.5012 - val_binary_accuracy: 0.9295
# Epoch 46/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5141 - binary_accuracy: 0.9014 - val_loss: 0.5140 - val_binary_accuracy: 0.9210
# Epoch 47/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5281 - binary_accuracy: 0.8910 - val_loss: 0.5120 - val_binary_accuracy: 0.9175
# Epoch 48/50
# 25/25 [==============================] - 0s 7ms/step - loss: 0.5514 - binary_accuracy: 0.8765 - val_loss: 0.4959 - val_binary_accuracy: 0.9386
# Epoch 49/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5184 - binary_accuracy: 0.9085 - val_loss: 0.5027 - val_binary_accuracy: 0.9217
# Epoch 50/50
# 25/25 [==============================] - 0s 6ms/step - loss: 0.5501 - binary_accuracy: 0.9010 - val_loss: 0.5154 - val_binary_accuracy: 0.9168

# %%
acc = history.history['binary_accuracy']
val_acc = history.history['val_binary_accuracy'] 
loss = history.history['loss'] 
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, 'bo', label='Training acc') 
plt.plot(epochs, val_acc, 'b', label='Validation acc') 
plt.title('Training and validation accuracy') 
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss') 
plt.plot(epochs, val_loss, 'b', label='Validation loss') 
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
def smooth_curve(points, factor=0.8): 
  smoothed_points = []
  for point in points:
      if smoothed_points:
          previous = smoothed_points[-1]
          smoothed_points.append(previous * factor + point * (1 - factor))
      else: 
          smoothed_points.append(point)
  return smoothed_points
plt.plot(epochs,
         smooth_curve(acc), 'bo', label='Smoothed training acc')
plt.plot(epochs,
         smooth_curve(val_acc), 'b', label='Smoothed validation acc')
plt.title('Training and validation accuracy') 
plt.legend()
plt.figure()
plt.plot(epochs,
         smooth_curve(loss), 'bo', label='Smoothed training loss')
plt.plot(epochs,
         smooth_curve(val_loss), 'b', label='Smoothed validation loss')
plt.title('Training and validation loss') 
plt.legend()
plt.show()

# %%
model.evaluate(X_test, Y_test)
# Out:
# 111/111 [==============================] - 0s 2ms/step - loss: 0.5101 - binary_accuracy: 0.9190
# [0.5101383924484253, 0.918995201587677]

# %%
predicted = np.array([int(x[0] > 0.5) for x in model.predict(X_test)])
print("Total accuracy:", np.sum(predicted==Y_test) / len(predicted) * 100., "%") 
matrix = confusion_matrix(Y_test, predicted)
print(matrix)
plt.figure(figsize=(7,7))
sns.heatmap(matrix,annot=True, square = True, fmt='g')
plt.show()
# Out:
# Total accuracy: 91.89952018063788 %
# [[3205  220]
#  [  67   51]]

# %% [markdown]
# ## Neural Network V2

# %%
neg, pos = np.bincount(df_ok['B8.1'])
total = neg + pos
print('Examples:\n    Total: {}\n    Positive: {} ({:.2f}% of total)\n'.format(
    total, pos, 100 * pos / total))
# Out:
# Examples:
#     Total: 17714
#     Positive: 627 (3.54% of total)

# %%
weight_for_0 = (1 / neg) * (total / 2.0)
weight_for_1 = (1 / pos) * (total / 2.0)

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 0.52
# Weight for class 1: 14.13

# %%
def baseline_model2():
  model = Sequential()
  model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
  model.add(BatchNormalization())
  model.add(Dropout(0.5))
  model.add(Dense(1, activation='sigmoid'))
  # Compile model
  model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['binary_accuracy'])
  return model

# %%
model2 = baseline_model2()

history = model2.fit(
  X_train, Y_train, batch_size = 512,
  epochs=50, validation_split = 0.1,
  class_weight=class_weight)
# Out:
# Epoch 1/50
# 25/25 [==============================] - 1s 13ms/step - loss: 0.8274 - binary_accuracy: 0.7334 - val_loss: 0.6790 - val_binary_accuracy: 0.7990
# Epoch 2/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.7391 - binary_accuracy: 0.7505 - val_loss: 0.6334 - val_binary_accuracy: 0.9062
# Epoch 3/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.7274 - binary_accuracy: 0.7682 - val_loss: 0.6098 - val_binary_accuracy: 0.9154
# Epoch 4/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6739 - binary_accuracy: 0.8041 - val_loss: 0.5837 - val_binary_accuracy: 0.9267
# Epoch 5/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6246 - binary_accuracy: 0.8082 - val_loss: 0.5615 - val_binary_accuracy: 0.9351
# Epoch 6/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6067 - binary_accuracy: 0.8249 - val_loss: 0.5397 - val_binary_accuracy: 0.9528
# Epoch 7/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6149 - binary_accuracy: 0.8418 - val_loss: 0.5359 - val_binary_accuracy: 0.9386
# Epoch 8/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5774 - binary_accuracy: 0.8549 - val_loss: 0.5231 - val_binary_accuracy: 0.9372
# Epoch 9/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5975 - binary_accuracy: 0.8506 - val_loss: 0.5181 - val_binary_accuracy: 0.9365
# Epoch 10/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5995 - binary_accuracy: 0.8618 - val_loss: 0.5065 - val_binary_accuracy: 0.9351
# Epoch 11/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5679 - binary_accuracy: 0.8554 - val_loss: 0.5085 - val_binary_accuracy: 0.9260
# Epoch 12/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5711 - binary_accuracy: 0.8643 - val_loss: 0.5037 - val_binary_accuracy: 0.9224
# Epoch 13/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5741 - binary_accuracy: 0.8583 - val_loss: 0.5051 - val_binary_accuracy: 0.9133
# Epoch 14/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5575 - binary_accuracy: 0.8571 - val_loss: 0.5037 - val_binary_accuracy: 0.9154
# Epoch 15/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5640 - binary_accuracy: 0.8655 - val_loss: 0.5025 - val_binary_accuracy: 0.9104
# Epoch 16/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5725 - binary_accuracy: 0.8593 - val_loss: 0.5074 - val_binary_accuracy: 0.9041
# Epoch 17/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5265 - binary_accuracy: 0.8694 - val_loss: 0.5030 - val_binary_accuracy: 0.9055
# Epoch 18/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5589 - binary_accuracy: 0.8669 - val_loss: 0.5045 - val_binary_accuracy: 0.8999
# Epoch 19/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5415 - binary_accuracy: 0.8710 - val_loss: 0.5048 - val_binary_accuracy: 0.8963
# Epoch 20/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5806 - binary_accuracy: 0.8642 - val_loss: 0.5089 - val_binary_accuracy: 0.8963
# Epoch 21/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5792 - binary_accuracy: 0.8635 - val_loss: 0.5100 - val_binary_accuracy: 0.8843
# Epoch 22/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5619 - binary_accuracy: 0.8661 - val_loss: 0.5047 - val_binary_accuracy: 0.8977
# Epoch 23/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5224 - binary_accuracy: 0.8711 - val_loss: 0.4932 - val_binary_accuracy: 0.8984
# Epoch 24/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5443 - binary_accuracy: 0.8692 - val_loss: 0.4946 - val_binary_accuracy: 0.8977
# Epoch 25/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5673 - binary_accuracy: 0.8717 - val_loss: 0.4979 - val_binary_accuracy: 0.8886
# Epoch 26/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5896 - binary_accuracy: 0.8669 - val_loss: 0.4970 - val_binary_accuracy: 0.8879
# Epoch 27/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5293 - binary_accuracy: 0.8707 - val_loss: 0.4937 - val_binary_accuracy: 0.8872
# Epoch 28/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5762 - binary_accuracy: 0.8647 - val_loss: 0.5002 - val_binary_accuracy: 0.8872
# Epoch 29/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5732 - binary_accuracy: 0.8674 - val_loss: 0.5045 - val_binary_accuracy: 0.8872
# Epoch 30/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5550 - binary_accuracy: 0.8716 - val_loss: 0.5086 - val_binary_accuracy: 0.8872
# Epoch 31/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5259 - binary_accuracy: 0.8750 - val_loss: 0.5058 - val_binary_accuracy: 0.8872
# Epoch 32/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5163 - binary_accuracy: 0.8738 - val_loss: 0.5049 - val_binary_accuracy: 0.8865
# Epoch 33/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5329 - binary_accuracy: 0.8647 - val_loss: 0.5097 - val_binary_accuracy: 0.8526
# Epoch 34/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5414 - binary_accuracy: 0.8693 - val_loss: 0.5154 - val_binary_accuracy: 0.8872
# Epoch 35/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5325 - binary_accuracy: 0.8723 - val_loss: 0.5120 - val_binary_accuracy: 0.8646
# Epoch 36/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5289 - binary_accuracy: 0.8705 - val_loss: 0.5050 - val_binary_accuracy: 0.8646
# Epoch 37/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5085 - binary_accuracy: 0.8670 - val_loss: 0.4987 - val_binary_accuracy: 0.8879
# Epoch 38/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5503 - binary_accuracy: 0.8672 - val_loss: 0.5041 - val_binary_accuracy: 0.8879
# Epoch 39/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5569 - binary_accuracy: 0.8707 - val_loss: 0.5016 - val_binary_accuracy: 0.8646
# Epoch 40/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5093 - binary_accuracy: 0.8713 - val_loss: 0.5003 - val_binary_accuracy: 0.8759
# Epoch 41/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5198 - binary_accuracy: 0.8718 - val_loss: 0.5003 - val_binary_accuracy: 0.8526
# Epoch 42/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5193 - binary_accuracy: 0.8701 - val_loss: 0.5002 - val_binary_accuracy: 0.8526
# Epoch 43/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5243 - binary_accuracy: 0.8652 - val_loss: 0.4967 - val_binary_accuracy: 0.8526
# Epoch 44/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5499 - binary_accuracy: 0.8639 - val_loss: 0.4988 - val_binary_accuracy: 0.8526
# Epoch 45/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5617 - binary_accuracy: 0.8676 - val_loss: 0.5032 - val_binary_accuracy: 0.8829
# Epoch 46/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5124 - binary_accuracy: 0.8718 - val_loss: 0.4958 - val_binary_accuracy: 0.8526
# Epoch 47/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5348 - binary_accuracy: 0.8650 - val_loss: 0.4953 - val_binary_accuracy: 0.8639
# Epoch 48/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5282 - binary_accuracy: 0.8689 - val_loss: 0.4921 - val_binary_accuracy: 0.8893
# Epoch 49/50
# 25/25 [==============================] - 0s 3ms/step - loss: 0.5226 - binary_accuracy: 0.8702 - val_loss: 0.4970 - val_binary_accuracy: 0.8526
# Epoch 50/50
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5330 - binary_accuracy: 0.8717 - val_loss: 0.5040 - val_binary_accuracy: 0.8597

# %%
acc = history.history['binary_accuracy']
val_acc = history.history['val_binary_accuracy'] 
loss = history.history['loss'] 
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, 'bo', label='Training acc') 
plt.plot(epochs, val_acc, 'b', label='Validation acc') 
plt.title('Training and validation accuracy') 
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss') 
plt.plot(epochs, val_loss, 'b', label='Validation loss') 
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
def smooth_curve(points, factor=0.8): 
  smoothed_points = []
  for point in points:
      if smoothed_points:
          previous = smoothed_points[-1]
          smoothed_points.append(previous * factor + point * (1 - factor))
      else: 
          smoothed_points.append(point)
  return smoothed_points
plt.plot(epochs,
         smooth_curve(acc), 'bo', label='Smoothed training acc')
plt.plot(epochs,
         smooth_curve(val_acc), 'b', label='Smoothed validation acc')
plt.title('Training and validation accuracy') 
plt.legend()
plt.figure()
plt.plot(epochs,
         smooth_curve(loss), 'bo', label='Smoothed training loss')
plt.plot(epochs,
         smooth_curve(val_loss), 'b', label='Smoothed validation loss')
plt.title('Training and validation loss') 
plt.legend()
plt.show()

# %%
model2.evaluate(X_test, Y_test)
# Out:
# 111/111 [==============================] - 0s 2ms/step - loss: 0.4923 - binary_accuracy: 0.8589
# [0.4923460781574249, 0.858876645565033]

# %%
predicted = np.array([int(x[0] > 0.5) for x in model2.predict(X_test)])
print("Total accuracy:", np.sum(predicted==Y_test) / len(predicted) * 100., "%") 
matrix = confusion_matrix(Y_test, predicted)
print(matrix)
plt.figure(figsize=(7,7))
sns.heatmap(matrix,annot=True, square = True, fmt='g')
plt.show()
# Out:
# Total accuracy: 85.88766581992661 %
# [[2978  447]
#  [  53   65]]
